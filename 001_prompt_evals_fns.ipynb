# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 7.833333333333333

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\n\ndef parse_s3_bucket(s3_uri):\n    match = re.match(r's3://([a-zA-Z0-9.-]+)/', s3_uri)\n    if match:\n        return match.group(1)\n    return None\n",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from an S3 URI in the format 's3://bucket-name/key/path'",
#       "format": "regex"
#     },
#     "score": 7.5,
#     "reasoning": "The solution works for the most common case of well-formed S3 URIs with trailing slashes, but has significant limitations in regex pattern correctness and lacks comprehensive S3 bucket name validation per AWS specification. The trailing slash requirement is overly strict since S3 URIs can represent both keys and buckets without keys."
#   },
#   {
#     "output": "\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template for AWS Lambda function\",\n  \"Parameters\": {\n    \"FunctionName\": {\n      \"Type\": \"String\",\n      \"Default\": \"my-lambda-function\",\n      \"Description\": \"Name of the Lambda function\"\n    },\n    \"RoleArn\": {\n      \"Type\": \"String\",\n      \"Description\": \"ARN of the IAM role for Lambda execution\"\n    },\n    \"Runtime\": {\n      \"Type\": \"String\",\n      \"Default\": \"python3.11\",\n      \"AllowedValues\": [\n        \"python3.11\",\n        \"python3.10\",\n        \"python3.9\",\n        \"nodejs18.x\",\n        \"nodejs16.x\",\n        \"java11\",\n        \"dotnet6\"\n      ],\n      \"Description\": \"Runtime environment for the Lambda function\"\n    }\n  },\n  \"Resources\": {\n    \"LambdaFunction\": {\n      \"Type\": \"AWS::Lambda::Function\",\n      \"Properties\": {\n        \"FunctionName\": {\n          \"Ref\": \"FunctionName\"\n        },\n        \"Runtime\": {\n          \"Ref\": \"Runtime\"\n        },\n        \"Role\": {\n          \"Ref\": \"RoleArn\"\n        },\n        \"Handler\": \"index.handler\",\n        \"Code\": {\n          \"ZipFile\": \"def handler(event, context):\\n    return {'statusCode': 200, 'body': 'Hello from Lambda!'}\\n\"\n        }\n      }\n    }\n  },\n  \"Outputs\": {\n    \"LambdaFunctionArn\": {\n      \"Description\": \"ARN of the Lambda function\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"LambdaFunction\",\n          \"Arn\"\n        ]\n      }\n    },\n    \"LambdaFunctionName\": {\n      \"Description\": \"Name of the Lambda function\",\n      \"Value\": {\n        \"Ref\": \"LambdaFunction\"\n      }\n    }\n  }\n}\n",
#     "test_case": {
#       "task": "Create a JSON CloudFormation template for an AWS Lambda function with basic properties including function name, runtime, and role ARN",
#       "format": "json"
#     },
#     "score": 8.0,
#     "reasoning": "The template demonstrates solid CloudFormation knowledge with proper structure and parameterization. However, it contains a significant logical error in how the RoleArn parameter is referenced, and the hardcoded Handler is incompatible with non-Python runtimes despite offering multiple runtime options. These issues would cause deployment failures or unexpected behavior in real-world scenarios."
#   },
#   {
#     "output": "\nfrom datetime import datetime\n\ndef convert_aws_timestamp(timestamp):\n    \"\"\"\n    Convert AWS timestamp (Unix epoch) to human-readable datetime string.\n    \n    Args:\n        timestamp: Unix epoch timestamp (integer or float, in seconds)\n    \n    Returns:\n        Human-readable datetime string in ISO 8601 format\n    \"\"\"\n    return datetime.utcfromtimestamp(timestamp).isoformat() + 'Z'\n\n\nif __name__ == \"__main__\":\n    print(convert_aws_timestamp(1609459200))\n    print(convert_aws_timestamp(1640995200))\n    print(convert_aws_timestamp(1672531200))\n",
#     "test_case": {
#       "task": "Write a Python function that converts an AWS timestamp (Unix epoch) to a human-readable datetime string",
#       "format": "python"
#     },
#     "score": 8.0,
#     "reasoning": "The solution addresses the core requirement and produces correct output for valid inputs. However, it uses a deprecated method that Python documentation warns against, and lacks defensive programming practices. The function would fail ungracefully on edge cases like invalid input types or out-of-range timestamps. For production AWS code, explicit timezone handling and input validation are important best practices."
#   }
# ]
