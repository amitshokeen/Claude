# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Must include runtime, memory size, timeout, and basic structure for AWS Lambda configuration"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Solution to Evaluate:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format:
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.666666666666667

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport boto3\nimport json\n\niam_client = boto3.client('iam')\nlambda_client = boto3.client('lambda')\n\nassume_role_policy = {\n    \"Version\": \"2012-10-17\",\n    \"Statement\": [\n        {\n            \"Effect\": \"Allow\",\n            \"Principal\": {\n                \"Service\": \"lambda.amazonaws.com\"\n            },\n            \"Action\": \"sts:AssumeRole\"\n        }\n    ]\n}\n\ns3_policy = {\n    \"Version\": \"2012-10-17\",\n    \"Statement\": [\n        {\n            \"Effect\": \"Allow\",\n            \"Action\": [\n                \"s3:GetObject\",\n                \"s3:PutObject\",\n                \"s3:DeleteObject\",\n                \"s3:ListBucket\"\n            ],\n            \"Resource\": \"*\"\n        }\n    ]\n}\n\nrole_name = \"lambda-s3-access-role\"\n\ntry:\n    role_response = iam_client.create_role(\n        RoleName=role_name,\n        AssumeRolePolicyDocument=json.dumps(assume_role_policy),\n        Description=\"IAM role for Lambda S3 access\"\n    )\n    role_arn = role_response['Role']['Arn']\n    print(f\"Created IAM role: {role_arn}\")\nexcept iam_client.exceptions.EntityAlreadyExistsException:\n    role_response = iam_client.get_role(RoleName=role_name)\n    role_arn = role_response['Role']['Arn']\n    print(f\"IAM role already exists: {role_arn}\")\n\niam_client.put_role_policy(\n    RoleName=role_name,\n    PolicyName=\"S3AccessPolicy\",\n    PolicyDocument=json.dumps(s3_policy)\n)\nprint(\"Attached S3 access policy to role\")\n\nimport time\ntime.sleep(10)\n\nlambda_function_config = {\n    \"FunctionName\": \"my-s3-function\",\n    \"Runtime\": \"python3.11\",\n    \"Role\": role_arn,\n    \"Handler\": \"index.handler\",\n    \"Code\": {\n        \"ZipFile\": b\"def handler(event, context):\\n    return {'statusCode': 200, 'body': 'Hello from Lambda'}\"\n    },\n    \"Timeout\": 60,\n    \"MemorySize\": 512,\n    \"Description\": \"Lambda function with S3 access\"\n}\n\ntry:\n    response = lambda_client.create_function(**lambda_function_config)\n    print(f\"Created Lambda function: {response['FunctionArn']}\")\n    print(json.dumps({\n        \"FunctionName\": response['FunctionName'],\n        \"Runtime\": response['Runtime'],\n        \"MemorySize\": response['MemorySize'],\n        \"Timeout\": response['Timeout'],\n        \"Role\": response['Role'],\n        \"Handler\": response['Handler']\n    }, indent=2))\nexcept lambda_client.exceptions.ResourceConflictException:\n    response = lambda_client.update_function_configuration(\n        FunctionName=\"my-s3-function\",\n        Timeout=60,\n        MemorySize=512,\n        Role=role_arn\n    )\n    print(f\"Updated Lambda function: {response['FunctionArn']}\")\n    print(json.dumps({\n        \"FunctionName\": response['FunctionName'],\n        \"Runtime\": response['Runtime'],\n        \"MemorySize\": response['MemorySize'],\n        \"Timeout\": response['Timeout'],\n        \"Role\": response['Role'],\n        \"Handler\": response['Handler']\n    }, indent=2))\n",
#     "test_case": {
#       "task": "Create an AWS Lambda function configuration that sets up a Python 3.11 runtime with 512MB memory, 60-second timeout, and an IAM role for S3 access",
#       "format": "json",
#       "solution_criteria": "Must include Runtime set to 'python3.11', MemorySize of 512, Timeout of 60, Role ARN, and Handler pointing to a valid Python function"
#     },
#     "score": 3.5,
#     "reasoning": "The solution successfully meets all specified requirements and demonstrates solid AWS API knowledge with appropriate error handling patterns. However, it contains implementation issues that would cause problems in production: the arbitrary sleep is unreliable, the IAM policy is overly permissive, and there's a potential race condition with put_role_policy. The solution would work in most cases but lacks production-ready robustness and security best practices."
#   },
#   {
#     "output": "\ndef extract_s3_info(event):\n    \"\"\"Extract bucket name and object key from S3 event record.\"\"\"\n    if 'Records' in event and len(event['Records']) > 0:\n        record = event['Records'][0]\n        bucket = record['s3']['bucket']['name']\n        key = record['s3']['object']['key']\n        return {'bucket': bucket, 'key': key}\n    return None\n",
#     "test_case": {
#       "task": "Write a Python function that extracts the bucket name and object key from an S3 event record received by a Lambda function",
#       "format": "python",
#       "solution_criteria": "Must parse the S3 event structure, extract bucket name from Records[0]['s3']['bucket']['name'] and key from Records[0]['s3']['object']['key'], and return both values"
#     },
#     "score": 8.0,
#     "reasoning": "The solution meets the core requirement of extracting bucket and key from a valid S3 event record. However, it lacks robustness for production use. The missing URL decoding is a common practical issue (e.g., 'my%20file.txt' vs 'my file.txt'), and error handling could be improved to distinguish between malformed events and missing records. Adding try-catch blocks and using urllib.parse.unquote() would significantly improve reliability."
#   },
#   {
#     "output": "\n^arn:aws:iam::\\d{12}:role/[a-zA-Z0-9+=,.@\\-_/]+$\n",
#     "test_case": {
#       "task": "Create a regular expression that validates AWS IAM role ARNs in the format: arn:aws:iam::ACCOUNT_ID:role/ROLE_NAME",
#       "format": "regex",
#       "solution_criteria": "Must match valid ARN format with 12-digit account ID and alphanumeric role names with hyphens, underscores, or forward slashes; must reject malformed ARNs"
#     },
#     "score": 8.5,
#     "reasoning": "The regex correctly matches the core ARN structure and validates the account ID format as required. It accepts the standard character set for role names per AWS specs. However, it's slightly over-permissive with special characters and doesn't enforce stricter boundaries around path separators. For most practical use cases, this solution works well, but could be refined for stricter validation of role naming conventions. The core functionality meets the stated criteria."
#   }
# ]
